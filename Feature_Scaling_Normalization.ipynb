# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/wine_data.csv',header= None,usecols = [0,1,2])
df
# Out:
#      0      1     2
# 0    1  14.23  1.71
# 1    1  13.20  1.78
# 2    1  13.16  2.36
# 3    1  14.37  1.95
# 4    1  13.24  2.59
# ..  ..    ...   ...
# 173  3  13.71  5.65
# 174  3  13.40  3.91
# 175  3  13.27  4.28
# 176  3  13.17  2.59
# 177  3  14.13  4.10
#
# [178 rows x 3 columns]

# %%
df.columns = ['Class Label','Alcohol','Malic acid']

# %%
df
# Out:
#      Class Label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
df.describe()
# Out:
#        Class Label     Alcohol  Malic acid
# count   178.000000  178.000000  178.000000
# mean      1.938202   13.000618    2.336348
# std       0.775035    0.811827    1.117146
# min       1.000000   11.030000    0.740000
# 25%       1.000000   12.362500    1.602500
# 50%       2.000000   13.050000    1.865000
# 75%       3.000000   13.677500    3.082500
# max       3.000000   14.830000    5.800000

# %%
df_features = df.iloc[:,1:]

# %%
df_target = df.iloc[:,0:1]

# %%
df_features
# Out:
#      Alcohol  Malic acid
# 0      14.23        1.71
# 1      13.20        1.78
# 2      13.16        2.36
# 3      14.37        1.95
# 4      13.24        2.59
# ..       ...         ...
# 173    13.71        5.65
# 174    13.40        3.91
# 175    13.27        4.28
# 176    13.17        2.59
# 177    14.13        4.10
#
# [178 rows x 2 columns]

# %%
df_target
# Out:
#      Class Label
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 173            3
# 174            3
# 175            3
# 176            3
# 177            3
#
# [178 rows x 1 columns]

# %%
# as we know before doing any kind of scaling we first do train test split

# %%
from sklearn.model_selection import train_test_split

# %%
fit the scaler on the train data to learn the scaling parameters

# %%
X_train,X_test,y_train,y_test = train_test_split(df_features,df_target,test_size = 0.3,random_state= 42)

# %%
X_train
# Out:
#      Alcohol  Malic acid
# 138    13.49        3.59
# 104    12.51        1.73
# 78     12.33        0.99
# 36     13.28        1.64
# 93     12.29        2.83
# ..       ...         ...
# 71     13.86        1.51
# 106    12.25        1.73
# 14     14.38        1.87
# 92     12.69        1.53
# 102    12.34        2.45
#
# [124 rows x 2 columns]

# %%
X_test
# Out:
#      Alcohol  Malic acid
# 19     13.64        3.10
# 45     14.21        4.04
# 140    12.93        2.81
# 30     13.73        1.50
# 67     12.37        1.17
# 16     14.30        1.92
# 119    12.00        3.43
# 174    13.40        3.91
# 109    11.61        1.35
# 141    13.36        2.56
# 24     13.50        1.81
# 150    13.50        3.12
# 41     13.41        3.84
# 118    12.77        3.43
# 15     13.63        1.81
# 111    12.52        2.43
# 113    11.41        0.74
# 82     12.08        1.13
# 9      13.86        1.35
# 114    12.08        1.39
# 18     14.19        1.59
# 66     13.11        1.01
# 60     12.33        1.10
# 169    13.40        4.60
# 171    12.77        2.39
# 164    13.78        2.76
# 117    12.42        1.61
# 65     12.37        1.21
# 90     12.08        1.83
# 55     13.56        1.73
# 29     14.02        1.68
# 128    12.37        1.63
# 145    13.16        3.57
# 31     13.58        1.66
# 12     13.75        1.73
# 42     13.88        1.89
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_scaled = scaler.transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled,columns = X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns = X_test.columns)

# %%
np.round(X_train.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.3         1.6
# 50%       12.9         1.9
# 75%       13.7         3.2
# max       14.8         5.8

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.3         0.2
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %%
df_min = df_features.min()
df_min
# Out:
# Alcohol       11.03
# Malic acid     0.74
# dtype: float64

# %%
df_max = df_features.max()
df_max
# Out:
# Alcohol       14.83
# Malic acid     5.80
# dtype: float64
